# %%
from zeta import *

# %%
math.plot([math.siegelz,siegelz],[1,50])

# %%
print [siegelz(i) for i in range(10,100)]
# Out:
# [mpf('-1.1766023155949061'), mpf('-1.0927042249347665'), mpf('-0.83094268294138773'), mpf('-0.35344086296312982'), mpf('0.33140548654657082'), mpf('1.1484589226740529'), mpf('1.949690807699805'), mpf('2.5342020707981709'), mpf('2.7005703467538171'), mpf('2.3246007551892385'), mpf('1.4379638431869812'), mpf('0.26901261554515965'), mpf('-0.79259767083893551'), mpf('-1.3223283860913981'), mpf('-1.047989028085945'), mpf('-0.018527317024319201'), mpf('1.3673510088697514'), mpf('2.4472250219511609'), mpf('2.6518062937788778'), mpf('1.8201738795239675'), mpf('0.36600965407092156'), mpf('-0.88359129384558988'), mpf('-1.147740360865936'), mpf('-0.20820067099501971'), mpf('1.3648807455371568'), mpf('2.5014104761288931'), mpf('2.3262385438267015'), mpf('0.81625265763632149'), mpf('-1.0926151731810925'), mpf('-2.1273937101112974'), mpf('-1.6471325714378886'), mpf('-0.21405059444762359'), mpf('0.77489750053619078'), mpf('0.21476192747158707'), mpf('-1.7073384474546338'), mpf('-3.5527216516219009'
# ...

# %%
print [math.siegeltheta(i) for i in range(10,100)]
# Out:
# [mpf('-3.0670743962898954'), mpf('-2.8107040917066555'), mpf('-2.508784765476693'), mpf('-2.1651260715635137'), mpf('-1.7829487004161499'), mpf('-1.3650113220230689'), mpf('-0.91370345465550651'), mpf('-0.43111498387316083'), mpf('0.080910757674949624'), mpf('0.62073575805735715'), mpf('1.1868948084444841'), mpf('1.7780695119107746'), mpf('2.3930672586436539'), mpf('3.030804034823396'), mpf('3.6902902290790949'), mpf('4.3706188101874917'), mpf('5.0709554004868869'), mpf('5.7905298795411531'), mpf('6.5286292340253862'), mpf('7.2845914308219273'), mpf('8.0578001365639906'), mpf('8.8476801422938323'), mpf('9.6536933793128394'), mpf('10.475335433702037'), mpf('11.312132483843603'), mpf('12.163638598649703'), mpf('13.029433344900722'), mpf('13.909119660707363'), mpf('14.802321959091433'), mpf('15.708684431372754'), mpf('16.627869524718896'), mpf('17.559556572065535'), mpf('18.503440555807895'), mpf('19.459230989323753'), mpf('20.426650902614739'), mpf('21.405435920224626'), mpf('22.395333
# ...

# %%
print [theta(i) for i in range(10,100)]
# Out:
# [mpf('-3.0670744001641115'), mpf('-2.8107040941089649'), mpf('-2.5087847670299332'), mpf('-2.1651260726036274'), mpf('-1.7829487011337484'), mpf('-1.3650113225310452'), mpf('-0.91370345502322814'), mpf('-0.43111498414463267'), mpf('0.08091075747101914'), mpf('0.62073575790177127'), mpf('1.1868948083241206'), mpf('1.778069511816484'), mpf('2.3930672585689434'), mpf('3.0308040347635825'), mpf('3.6902902290307531'), mpf('4.370618810148077'), mpf('5.0709554004544941'), mpf('5.7905298795143318'), mpf('6.5286292340030316'), mpf('7.2845914308031672'), mpf('8.057800136548158'), mpf('8.8476801422803959'), mpf('9.6536933793013748'), mpf('10.475335433692209'), mpf('11.312132483835136'), mpf('12.163638598642377'), mpf('13.029433344894363'), mpf('13.909119660701815'), mpf('14.802321959086582'), mpf('15.708684431368489'), mpf('16.627869524715145'), mpf('17.559556572062217'), mpf('18.503440555804954'), mpf('19.459230989321142'), mpf('20.426650902612408'), mpf('21.405435920222544'), mpf('22.39533342
# ...

# %%
zeta(math.mpc(0.5,200))
# Out:
# mpc(real='4.5905773749690519', imag='-3.1894012475791453')

# %%
math.zeta(math.mpc(0.435,213))
# Out:
# mpc(real='0.068680477917937841', imag='-0.85596914588593553')
